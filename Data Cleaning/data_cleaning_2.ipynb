# %%
import numpy as np
import pandas as pd

# %%
philo = pd.read_csv('jstor-philosophy.csv')
philo.head()
# Out:
#                                             abstract datePublished  docType  \
# 0  The concept of ‘class struggle’ (<em>jieji dou...    2019-01-01  chapter
# 1  On returning to office in 2007, the FSLN intro...    2020-01-01  chapter
# 2  Through public policies, governments have enor...    2019-01-01  chapter
# 3  Thai friends, knowing of my longstanding inter...    2019-01-01  chapter
# 4  It has become commonplace, in the current conj...    2019-01-01  chapter
#
#                                             fullText  \
# 0  AFTERLIVES OF CHINESE COMMUNISM 29 4 阶级斗争 Clas...
# 1  6. The difference the revolution made: decisio...
# 2  1 On studying policy successes in Australia an...
# 3  1 Introduction Video content for this chapter ...
# 4  CHAPTER 10 SEVEN THESES ON RADICAL NON-RACIALI...
#
#                                                   id  \
# 0          http://www.jstor.org/stable/j.ctvk3gng9.7
# 1         http://www.jstor.org/stable/j.ctvrs8z5t.11
# ...

# %%
philo['tdmCategory'].value_counts()
# Out:
# Philosophy - Applied philosophy                                                                                                                                                                                                                                                                                                          6349
# Political science - Military science                                                                                                                                                                                                                                                                                                     2008
# ...

# %%
philo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17218 entries, 0 to 17217
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   abstract         13461 non-null  object
#  1   datePublished    17218 non-null  object
#  2   docType          17218 non-null  object
#  3   fullText         17218 non-null  object
#  4   id               17218 non-null  object
#  5   isPartOf         17218 non-null  object
#  6   language         17218 non-null  object
#  7   pageCount        16978 non-null  float64
#  8   pageEnd          17210 non-null  object
#  9   pageStart        17210 non-null  object
#  10  pagination       17210 non-null  object
#  11  provider         17218 non-null  object
#  12  publicationYear  17218 non-null  int64
#  13  sourceCategory   17218 non-null  object
#  14  tdmCategory      17218 non-null  object
#  15  title            17218 non-null  object
# ...

# %%
poli = pd.read_csv('jstor-political-science.csv')
poli.head()
# Out:
#                                             abstract datePublished  docType  \
# 0  Albeit focusing on rather different topics, th...    2017-01-01  chapter
# 1  Japan began to change dramatically as soon as ...    2017-01-01  chapter
# 2                                                NaN    2019-01-01  chapter
# 3                                                NaN    2019-01-01  chapter
# 4  June 6, 1944: D-Day, the start of the invasion...    2018-01-01  chapter
#
#                                             fullText  \
# 0  CHAPTER 11 rePresentinG Others, PresentinG seL...
# 1  15 Hungary, Confused, and Afraid Waiting Japan...
# 2  Umar I (Umar ibn al-Khattab) (c.581–644). Seco...
# 3  Notes on contributors Kenneth Brophy is senior...
# 4  Part 1 The Politics and Cultures of Liberation...
#
#                                                   id  \
# 0        http://www.jstor.org/stable/j.ctt1wf4dqz.16
# 1        http://www.jstor.org/stable/j.ctt1pk3jj7.21
# ...

# %%
poli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6149 entries, 0 to 6148
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   abstract         4356 non-null   object
#  1   datePublished    6149 non-null   object
#  2   docType          6149 non-null   object
#  3   fullText         6149 non-null   object
#  4   id               6149 non-null   object
#  5   isPartOf         6149 non-null   object
#  6   language         6149 non-null   object
#  7   pageCount        6084 non-null   float64
#  8   pageEnd          6144 non-null   object
#  9   pageStart        6144 non-null   object
#  10  pagination       6144 non-null   object
#  11  provider         6149 non-null   object
#  12  publicationYear  6149 non-null   int64
#  13  sourceCategory   6149 non-null   object
#  14  tdmCategory      6149 non-null   object
#  15  title            6149 non-null   object
# ...

# %%
usb = pd.read_csv('uscb-presidency-project.csv')
usb.head()
# Out:
# C:\Users\Akoua Orsot\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Unnamed: 0                                                URL  \
# 0          0  https://www.presidency.ucsb.edu/documents/rema...
# 1          1  https://www.presidency.ucsb.edu/documents/rema...
# 2          2  https://www.presidency.ucsb.edu/documents/rema...
# 3          3  https://www.presidency.ucsb.edu/documents/stat...
# 4          4  https://www.presidency.ucsb.edu/documents/memo...
#
#             Person           Date  \
# 0  Joseph R. Biden  July 29, 2021
# 1  Joseph R. Biden  July 29, 2021
# 2  Joseph R. Biden  July 28, 2021
# 3  Joseph R. Biden  July 28, 2021
# 4  Joseph R. Biden  July 28, 2021
#
#                                                Title  \
# 0  Remarks on Efforts to Combat the Spread of the...
# ...

# %%
usb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135167 entries, 0 to 135166
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  135167 non-null  object
#  1   URL         135167 non-null  object
#  2   Person      135166 non-null  object
#  3   Date        135166 non-null  object
#  4   Title       135166 non-null  object
#  5   Text        77945 non-null   object
# dtypes: object(6)
# memory usage: 6.2+ MB

# %%
ams = pd.read_csv('american-rhetoric-speeches.csv')
ams.head()
# Out:
#    Unnamed: 0                                               Link  \
# 0           0  https://www.americanrhetoric.com/speeches/1is2...
# 1           1  https://www.americanrhetoric.com/speeches/aaro...
# 2           2  https://www.americanrhetoric.com/speeches/gett...
# 3           3  https://www.americanrhetoric.com/speeches/gett...
# 4           4  https://www.americanrhetoric.com/speeches/abdu...
#
#                             Author  \
# 0                      1 is 2 Many
# 1                     Aaron Swartz
# 2                  Abraham Lincoln
# 3                  Abraham Lincoln
# 4  Abdullatif bin Rashid Al Zayani
#
#                                                 Date  \
# 0                                            No Date
# 1  21 May 2012 [AUTHENTICITY CERTIFIED: Text vers...
# 2  19 November 1863 Fourscore and seven years ago...
# 3  19 November 1863 Fourscore and seven years ago...
# 4                                  15 September 2020
#
# ...

# %%
ams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1652 entries, 0 to 1651
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1652 non-null   int64
#  1   Link        1652 non-null   object
#  2   Author      1652 non-null   object
#  3   Date        1651 non-null   object
#  4   Content     1652 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 64.7+ KB
